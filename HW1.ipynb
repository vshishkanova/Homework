# %%
pinguin = int(input( "Введите число от 1 до 9: "))

a = '    _~_    '
b = '   (o o)   '
c = '  /  V  \  '
d = ' /(  _  )\ '
e = '   ^^ ^^   '
 
print(a*pinguin)
print(b*pinguin)
print(c*pinguin)
print(d*pinguin)
print(e*pinguin)
# Out:
# Введите число от 1 до 9: 6
#     _~_        _~_        _~_        _~_        _~_        _~_
#    (o o)      (o o)      (o o)      (o o)      (o o)      (o o)
#   /  V  \    /  V  \    /  V  \    /  V  \    /  V  \    /  V  \
#  /(  _  )\  /(  _  )\  /(  _  )\  /(  _  )\  /(  _  )\  /(  _  )\
#    ^^ ^^      ^^ ^^      ^^ ^^      ^^ ^^      ^^ ^^      ^^ ^^

# %%
sentence = "мы веселые медузы"
print("Количество символов в строке: ")
print(len(sentence)) 

words = sentence.split()
print("Количество слов в строке")
print(len(words))
# Out:
# Количество символов в строке:
# 17
# Количество слов в строке
# 3

# %%
sentence = "Не пей вина, Гертруда,пьянство не красит дам. Напьешься в хлам - и станет противно соратникам и друзьям."
print(sentence[3])
print(sentence[-2])
print(sentence[0:5])
print(sentence[:-2])
print(sentence[1::2])
print(sentence[::2])
print(sentence[::-1])
print(sentence[::-2])
print(len(sentence))
# Out:
# п
# м
# Не пе
# Не пей вина, Гертруда,пьянство не красит дам. Напьешься в хлам - и станет противно соратникам и друзья
# епйвн,Гррд,ьнтон рстдм аьшс  лм-исае ртвосртиа  рзя.
# Н е иа етуапясв екаи а.Нпеьявха   тнтпоин оанкмидуьм
# .мяьзурд и макинтарос онвиторп тенатс и - малх в ясьшеьпаН .мад тисарк ен овтсняьп,адуртреГ ,анив йеп еН
# .язр  аитрсовтр еаси-мл  сшьа мдтср нотнь,дррГ,нвйпе
# 104

# %%
word = input("Введите слово: ") 

if word.lower() == word[::-1].lower():
    print ("Yes")
else: 
    print ("No")
# Out:
# Введите слово: lollypop
# No

# %%
poem = input("Введите слово: ") 

text = ["законы физики рядом с черной дырой уже не работают в том представлении в котором мы привыкли\
пространство время искривляется и все события протекают уже совсем по другому\
словно пылесос черная дыра поглощает все что находится около нее планеты астероиды свет и прочее\
ранее считалось что черная дыра ничего не излучает но как доказал стивен хокинг черная дыра излучает антивещество\
то есть поедает вещество и выделяет антивещество\nранее думали что если кинуть в черную дыру человека то ему труба порвет на субатомы\
но как оказалось по некоторым уравнениям есть определенные траектории путешествия сквозь черную дыру чтоб чувствовать себя нормально\
правда не ясно что будет за ней другой мир или ничего\nобласть вокруг черной дыры которая интересна называется горизонтом событий\
если туда полететь не зная волшебное уравнение то будет конечно не очень\nнаблюдатель будет видеть как космический корабль влетает в горизонт событий и крайне медленно потом отдаляется пока не застынет в центре\
у самого же космонавта дела будут идти совсем по другому\
искривленное пространство будет лепить из него как из пластилина различные формы пока наконец не разорвет все на субатомы\
но для внешнего наблюдателя космонавт навсегда останется улыбающимся и махающим в иллюминатор застывшим изображением"]

words = ['законы', 'физики', 'рядом', 'с', 'черной', 'дырой', 'уже', 'не', 'работают', 'в', 'том', 'представлении', 'в', 'котором', 'мы', 'привыкли', 
        'пространство', 'время', 'искривляется', 'и', 'все', 'события', 'протекают', 'уже', 'совсем', 'по', 'другому', 
        'словно', 'пылесос', 'черная', 'дыра', 'поглощает', 'все', 'что', 'находится', 'около', 'нее', 'планеты', 'астероиды', 'свет', 'и', 'прочее', 
        'ранее', 'считалось', 'что', 'черная', 'дыра', 'ничего', 'не', 'излучает', 'но', 'как', 'доказал', 'стивен', 'хокинг', 'черная', 'дыра', 'излучает', 'антивещество', 
        'то', 'есть', 'поедает', 'вещество', 'и', 'выделяет', 'антивещество', 
        'ранее', 'думали', 'что', 'если', 'кинуть', 'в', 'черную', 'дыру', 'человека', 'то', 'ему', 'труба', 'порвет', 'на', 'субатомы', 
        'но', 'как', 'оказалось', 'по', 'некоторым', 'уравнениям', 'есть', 'определенные', 'траектории', 'путешествия', 'сквозь', 'черную', 'дыру', 'чтоб', 'чувствовать', 'себя', 'нормально', 
        'правда', 'не', 'ясно', 'что', 'будет', 'за', 'ней', 'другой', 'мир', 'или', 'ничего', 
        'область', 'вокруг', 'черной', 'дыры', 'которая', 'интересна', 'называется', 'горизонтом', 'событий', 
        'если', 'туда', 'полететь', 'не', 'зная', 'волшебное', 'уравнение', 'то', 'будет', 'конечно', 'не', 'очень',
        'наблюдатель', 'будет', 'видеть', 'как', 'космический', 'корабль', 'влетает', 'в', 'горизонт', 'событий', 'и', 'крайне', 'медленно', 'потом', 'отдаляется', 'пока', 'не', 'застынет', 'в', 'центре', 
        'у', 'самого', 'же', 'космонавта', 'дела', 'будут', 'идти', 'совсем', 'по', 'другому', 
        'искривленное', 'пространство', 'будет', 'лепить', 'из', 'него', 'как', 'из', 'пластилина', 'различные', 'формы', 'пока', 'наконец', 'не', 'разорвет', 'все', 'на', 'субатомы', 
        'но', 'для', 'внешнего', 'наблюдателя', 'космонавт', 'навсегда', 'останется', 'улыбающимся', 'и', 'махающим', 'в', 'иллюминатор', 'застывшим', 'изображением']


if poem not in words:
    print("Данное слово отсутствует. Мы добавили его в текст.")
    text.append(poem)
    print(text)
else:
    print("Данное слово присутствует. Это слово встречается в тексте раз: ")
    print(words.count(poem))
# Out:
# Введите слово: перстень
# Данное слово отсутствует. Мы можем его добавить.
# ['законы физики рядом с черной дырой уже не работают в том представлении в котором мы привыклипространство время искривляется и все события протекают уже совсем по другомусловно пылесос черная дыра поглощает все что находится около нее планеты астероиды свет и прочееранее считалось что черная дыра ничего не излучает но как доказал стивен хокинг черная дыра излучает антивеществото есть поедает вещество и выделяет антивещество\nранее думали что если кинуть в черную дыру человека то ему труба порвет на субатомыно как оказалось по некоторым уравнениям есть определенные траектории путешествия сквозь черную дыру чтоб чувствовать себя нормальноправда не ясно что будет за ней другой мир или ничего\nобласть вокруг черной дыры которая интересна называется горизонтом событийесли туда полететь не зная волшебное уравнение то будет конечно не очень\nнаблюдатель будет видеть как космический корабль влетает в горизонт событий и крайне медленно потом отдаляется пока не застынет в центреу самого же космонавта дела будут идти совсем по другомуискривленное пространство будет лепить из него как из пластилина различные формы пока наконец не разорвет все на субатомыно для внешнего наблюдателя космонавт навсегда останется улыбающимся и махающим в иллюминатор застывшим изображением', 'перстень']
